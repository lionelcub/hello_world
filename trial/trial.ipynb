# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("antibiotic-use-in-livestock.csv")

# %%
data.head()
# Out:
#         Entity Code  Year  Antibiotic use in livestock (mg/PCU)
# 0  Afghanistan  AFG  2010                                  16.3
# 1      Albania  ALB  2010                                  38.2
# 2      Algeria  DZA  2010                                  65.1
# 3       Angola  AGO  2010                                  25.1
# 4    Argentina  ARG  2010                                  29.6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Data columns (total 4 columns):
# Entity                                  291 non-null object
# Code                                    291 non-null object
# Year                                    291 non-null int64
# Antibiotic use in livestock (mg/PCU)    291 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 9.2+ KB

# %%
data.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Antibiotic use in livestock (mg/PCU)'], dtype='object')

# %%
data.sort_values(by="Antibiotic use in livestock (mg/PCU)", ascending=False)
# Out:
#                        Entity Code  Year  Antibiotic use in livestock (mg/PCU)
# 56                     Cyprus  CYP  2015                                 434.2
# 54                     Cyprus  CYP  2013                                 425.8
# 136                     Italy  ITA  2010                                 421.1
# 248                     Spain  ESP  2014                                 418.8
# 52                     Cyprus  CYP  2011                                 407.6
# 51                     Cyprus  CYP  2010                                 407.6
# 249                     Spain  ESP  2015                                 402.0
# 53                     Cyprus  CYP  2012                                 396.5
# 55                     Cyprus  CYP  2014                                 391.5
# 137                     Italy  ITA  2011                                 371.0
# 140                     Italy  ITA  2014                                 359.9
# ...
